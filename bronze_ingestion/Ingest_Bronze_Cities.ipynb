# %%
# %run "../setup/functions"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
# ...

# %%
dbutils.widgets.text("start_date", "2020-04-22")
start_date = dbutils.widgets.get("start_date")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
dbutils.widgets.text("terminate_date", "2020-04-27")
end_date = dbutils.widgets.get("terminate_date")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ##Ingesting Raw Data

# %%
LocationType = StructType(fields=[
    StructField("type", StringType(), True),
    StructField("coordinates", StringType(), True)
])
                                                        
schema_df = StructType(fields=[
    StructField("uid", StringType(), True),
    StructField("country_iso2", StringType(), True),
    StructField("country_iso3", StringType(), True),
    StructField("country_code", StringType(), True),
    StructField("state", StringType(), True),
    StructField("CHAVE_DATA_DIA", StringType(), True),
    StructField("country", StringType(), True),
    StructField("county", StringType(), True),
    StructField("combined_name", StringType(), True),
    StructField("population", IntegerType(), True),
    StructField("loc", LocationType, True),
    StructField("date", StringType(), True),
    StructField("confirmed", IntegerType(), True),
    StructField("deaths", IntegerType(), True),
    StructField("confirmed_daily", IntegerType(), True),
    StructField("deaths_daily", IntegerType(), True)
])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
get_state_raw_data("california",schema_df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[46]: DataFrame[combined_name: string, confirmed: bigint, confirmed_daily: bigint, country: string, country_code: string, country_iso2: string, country_iso3: string, county: string, date: string, deaths: bigint, deaths_daily: bigint, loc: struct&lt;coordinates:string,type:string&gt;, population: bigint, state: string, uid: string, CHAVE_DATA_DIA: int]</div>

# %%
display(spark.read.format("json").load(f"{bronze_folder_path}california"))

# %%
get_state_raw_data("new york",schema_df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[48]: DataFrame[combined_name: string, confirmed: bigint, confirmed_daily: bigint, country: string, country_code: string, country_iso2: string, country_iso3: string, county: string, date: string, deaths: bigint, deaths_daily: bigint, loc: struct&lt;coordinates:string,type:string&gt;, population: bigint, state: string, uid: string, CHAVE_DATA_DIA: int]</div>
